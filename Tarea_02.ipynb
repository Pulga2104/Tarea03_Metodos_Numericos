# %% [markdown]
# # Tarea 01
# Nombre: Josue Calvopiña
#
# Grupo: 1CC
#
# Fecha:

# %% [markdown]
# 1. Calcule los errores absoluto y relativo en las aproximaciones de p por p*
#
#     a. $$𝑝 = π, 𝑝^* = \frac{22}{7}$$
#
#     Error absoluto:
#
#     $|p - p^{*}| = |3.14159265... - 3.14285714...| \approx 1.2645 \times 10^{-3}$
#
#     Error relativo:
#
#     $\frac{|p - p^{*}|}{|p|} = \frac{|3.14159265... - 3.14285714...|}{3.14159265...} \approx 4.025 \times 10^{-4}$
#
#     b. $$p = \pi, p^{*} = 3.1416$$
#
#     Error absoluto:
#
#     $|p - p^{*}| = |3.14159265... - 3.1416| \approx 7.346 \times 10^{-6}$
#
#     Error relativo:
#
#     $\frac{|p - p^{*}|}{|p|} = \frac{7.346 \times 10^{-6}}{\pi} \approx 2.338 \times 10^{-6}$
#
#     c. $$p = e, p^{*} = 2.718$$
#
#     Error absoluto:
#
#     $|p - p^{*}| = |e - 2.718| \approx 2.818 \times 10^{-4}$
#
#     Error relativo:
#
#     $\frac{|p - p^{*}|}{|p|} = \frac{2.818 \times 10^{-4}}{e} \approx 1.036 \times 10^{-4}$
#
#     d. $$p = \sqrt{2}, p^{*} = 1.414$$
#
#     Error absoluto:
#
#     $|p - p^{*}| = |\sqrt{2} - 1.414| \approx 2.1356 \times 10^{-4}$
#
#     Error relativo:
#
#     $\frac{|p - p^{*}|}{|p|} = \frac{2.1356 \times 10^{-4}}{\sqrt{2}} \approx 1.51 \times 10^{-4}$

# %% [markdown]
# 2. Calcule los errores absoluto y relativo en las aproximaciones de p por p*
#
#     a. $$p = e^{10}, p^{*} = 22000$$
#
#     Error absoluto:
#
#     $|p - p^{*}| = |e^{10} - 22000| = |22026.4657... - 22000| \approx 26.4657$
#
#     Error relativo:
#
#     $\frac{|p - p^{*}|}{|p|} = \frac{26.4657}{22026.4657...} \approx 1.2015 \times 10^{-3}$
#
#     b. $$p = 10^{\pi}, p^{*} = 1400$$
#
#     Error absoluto:
#
#     $|p - p^{*}| = |10^{\pi} - 1400| = |1385.4557... - 1400| \approx 14.5443$
#
#     Error relativo:
#
#     $\frac{|p - p^{*}|}{|p|} = \frac{14.5443}{1385.4557...} \approx 0.0105$
#
#     c. $$p = 8!, p^{*} = 39900$$
#
#     Error absoluto:
#
#     $|p - p^{*}| = |8! - 39900| =|40320 - 39900| = 420$
#
#     Error relativo:
#
#     $\frac{|p - p^{*}|}{|p|} = \frac{420}{40320} \approx 0.010416...$
#
#     d. $$p = 9!, p^{*} = \sqrt{18\pi}(\frac{9}{e})^{9}$$
#
#     Error absoluto:
#
#     $|p - p^{*}| = |9! - \sqrt{18\pi}(\frac{9}{e})^{9}| = |362880 - 359255.77...| \approx 3624.22...$
#
#     Error relativo:
#
#     $\frac{|p - p^{*}|}{|p|} = \frac{3624.22...}{362880} \approx 0.009987$

# %% [markdown]
# 3. Encuentre el intervalo más largo en el que se debe encontrar $𝑝^{∗}$ para aproximarse a 𝑝 con error relativo máximo de 10−4 para cada valor de 𝑝.
#
#     Despeje de $𝑝^{∗}$:
#
#     $|p - p^{*}| \le |p| \cdot 10^{-4}$
#
#     $-|p| \cdot 10^{-4} \le p - p^{*} \le |p| \cdot 10^{-4}$
#
#     $-p - p(10^{-4}) \le -p^{*} \le -p + p(10^{-4})$
#
#     $p - p(10^{-4}) \le p^{*} \le p + p(10^{-4})$
#
#     $p(1 - 10^{-4}) \le p^{*} \le p(1 + 10^{-4})$
#
#     $p(0.9999) \le p^{*} \le p(1.0001)$
#
#     a. $\pi$
#
#     Limite inferior:
#
#     $p(0.9999) = (\pi \cdot 0.9999) \approx (3.14159265... \cdot 0.9999) \approx 3.14127849...$
#
#     Limite superior:
#
#     $p(1.0001) = (\pi \cdot 1.0001) \approx (3.14159265... \cdot  1.0001) \approx 3.14190681...$
#
#     Intervalo:
#
#     $p^{*}$ debe estar en $[3.141278, 3.141907]$.
#
#     b. $e$
#
#     Limite inferior:
#
#     $p(0.9999) = (e \cdot 0.9999) \approx (2.71828182... \cdot 0.9999) \approx 2.71801...$
#
#     Limite superior:
#
#     $p(1.0001) = (e \cdot 1.0001) \approx (2.71828182... \cdot  1.0001) \approx 2.718553657...$
#
#     Intervalo:
#
#     $p^{*}$ debe estar en $[2.71801, 2.718553657]$.
#
#     c. $\sqrt{2}$
#
#     Limite inferior:
#
#     $p(0.9999) = (\sqrt{2} \cdot 0.9999) \approx (1.414213562... \cdot 0.9999) \approx 1.41407214...$
#
#     Limite superior:
#
#     $p(1.0001) = (\sqrt{2} \cdot 1.0001) \approx (2.71828182... \cdot  1.0001) \approx 1.41435498...$
#
#     Intervalo:
#
#     $p^{*}$ debe estar en $[1.41407214, 1.41435498]$.
#
#     d. $\sqrt[3]{7}$
#
#     Limite inferior:
#
#     $p(0.9999) = (\sqrt[3]{7} \cdot 0.9999) \approx (1.91293118... \cdot 0.9999) \approx 1.91273989...$
#
#     Limite superior:
#
#     $p(1.0001) = (\sqrt[3]{7} \cdot 1.0001) \approx (1.91293118... \cdot  1.0001) \approx 1.91312247...$
#
#     Intervalo:
#
#     $p^{*}$ debe estar en $[1.91273989, 1.91312247]$.

# %% [markdown]
# 4. Use la aritmética de redondeo de tres dígitos para realizar lo siguiente. Calcule los errores absoluto y relativo con el valor exacto determinado para por lo menos cinco dígitos.
#
# a. $\frac{(13/14) - (5/7)}{2e - 5.4}$
#
# $p = \frac{(0.9285714) - (0.7142857)}{2(2.7182818) - 5.4} \approx 5.8606204$
#
# $p^{*} = \frac{(0.929) - (0.714)}{2(2.71) - 5.4} \approx 5.375$
#
# Error relativo:
#
# $\frac{|p - p^{*}|}{|p|} = \frac{0.4856204}{5.8606204} \approx 8.2008 \times 10^{-2}$
#
# Error absoluto:
#
# $|p - p^{*}| = |5.8606204 - 5.375| \approx 4.806 \times 10^{-1}$
#
# b. $-10\pi + 6e - \frac{3}{61}$ 27
#
# $p = -10(3.14159) + 6(2.71828) - (0.049180) \approx -15.155416$
#
# $p^{*} = -31.4 + 16.3 - 0.04 \approx -15.1$
#
# Error relativo:
#
# $\frac{|p - p^{*}|}{|p|} = \frac{0.055416}{|-15.155416|} \approx 3.65 \times 10^{-3}$
#
# Error absoluto:
#
# $|p - p^{*}| = |-15.155416 - (-15.1)| \approx 5.5416 \times 10^{-2}$
#
# c. $(\frac{2}{9}) \cdot (\frac{9}{11})$
#
# $p = (\frac{2}{9}) \cdot (\frac{9}{11})$
#
# $p^{*} = -31.4 + 16.3 - 0.04 \approx -15.1$
#
# Error relativo:
#
# $\frac{|p - p^{*}|}{|p|} = \frac{0.055416}{|-15.155416|} \approx 3.65 \times 10^{-3}$
#
# Error absoluto:
#
# $|p - p^{*}| = |-15.155416 - (-15.1)| \approx 5.5416 \times 10^{-2}$
